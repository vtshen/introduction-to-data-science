# %%
import twitter
# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information
# on Twitter's OAuth implementation.
CONSUMER_KEY = 'LItYWbMkoEt6KRbznvoCQcP5i'
CONSUMER_SECRET = 'NVhC9F6W77iO99Ut1aJDX7ut0DP8GqHyVFdtEWpRboFlpcvqnv'
OAUTH_TOKEN = '2870997399-kNPx3rODRpF1YwmxQm9AQ4pIArfoHHgU7M8jR8Y'
OAUTH_TOKEN_SECRET = 'sh6aEqDKoDJ2biDWtXXH4PCpiR4IBhKvOFLEAEWDRUym1'
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
 CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)
# Nothing to see by displaying twitter_api except that it's now a
# defined variable
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f9a0de5b240>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
WORLD_WOE_ID = 1
US_WOE_ID = 23424977
# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

# %%
import json
# print(json.dumps(world_trends, indent=2), "\n",json. dumps(us_trends, indent=2))

# %%
# find the intersection of two sets (world trend and US trend)
world_trends_set = set([trend['name' ] for trend in world_trends[0]['trends' ]])
us_trends_set = set([trend['name' ] for trend in us_trends[0]['trends' ]])
common_trends = world_trends_set.intersection(us_trends_set)
print(common_trends)
# Out:
# {'Shaun Livingston', '#HappyInternationalWomensDay'}

# %%
import twitter

q = '#illini' # how to use query operators to build a query? see https://dev.twitter.com/rest/public/search 
count = 10 # count is The number of tweets to return per page
# See https://dev.twitter.com/docs/api/1.1/get/search/tweets
search_results = twitter_api.search.tweets(q = q, count = count) # search_results contains two fields: "statuses" and "search_metadata" 
statuses = search_results['statuses' ]
# Iterate through 5 more batches of results by following the cursor
for _ in range(5):
    print("Length of statuses" , len(statuses))
    try:
        next_results = search_results['search_metadata' ]['next_results' ] # get information related to next page
    except KeyError: # No more results when next_results doesn't exist
        break
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=' ) for kv in next_results[1:].split("&" ) ]) # get the arguments to search the next page
    search_results = twitter_api.search.tweets(**kwargs) # here double stars unpack the values in dict into arguments of the function
    statuses += search_results['statuses' ]
    
# print(json.dumps(statuses[0], indent=4))
# Out:
# Length of statuses 10
# Length of statuses
#  20
# Length of statuses
#  20
# {
#     "in_reply_to_status_id_str": null,
#     "id": 574671140611751937,
#     "truncated": false,
#     "in_reply_to_screen_name": null,
#     "created_at": "Sun Mar 08 20:40:51 +0000 2015",
#     "entities": {
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "IlliniWrestling",
#                 "id": 41606345,
#                 "id_str": "41606345",
#                 "name": "Illinois Wrestling",
#                 "indices": [
#                     3,
#                     19
#                 ]
#             }
#         ],
#         "hashtags": [
#             {
#                 "text": "Illini",
#                 "indices": [
#                     53,
#                     60
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "retweeted_status": {
#         "in_reply_to_status_id_str": null,
#         "id": 574665980976197632,
#         "truncated": false,
#         "in_reply_to_screen_name": null,
#         "created_at": "Sun Mar 08 20:20:21 +0000 2015",
#         "entities": {
#             "symbols": [],
#             "user_mentions": [],
#             "hashtags": [
#                 {
#                     "text": "Illini",
#                     "indices": [
#                         32,
#                         39
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "favorite_count": 4,
#         "geo": null,
#         "id_str": "574665980976197632",
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "retweet_count": 1,
#         "user": {
#             "followers_count": 9096,
#             "listed_count": 124,
#             "location": "Champaign, IL",
#             "id": 41606345,
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_location": null,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/456661258826031104/FQAt8OZH_normal.jpeg",
#             "default_profile_image": false,
#             "following": false,
#             "profile_use_background_image": true,
#             "profile_link_color": "0084B4",
#             "is_translation_enabled": false,
#             "follow_request_sent": false,
#             "friends_count": 123,
#             "url": "http://t.co/CKhZnzVLcQ",
#             "created_at": "Thu May 21 15:22:38 +0000 2009",
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "expanded_url": "http://bit.ly/ILSocMedia",
#                             "indices": [
#                                 106,
#                                 128
#                             ],
#                             "url": "http://t.co/iSs9XwBnZ1",
#                             "display_url": "bit.ly/ILSocMedia"
#                         }
#                     ]
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "expanded_url": "http://www.fightingillini.com/",
#                             "indices": [
#                                 0,
#                                 22
#                             ],
#                             "url": "http://t.co/CKhZnzVLcQ",
#                             "display_url": "fightingillini.com"
#                         }
#                     ]
#                 }
#             },
#             "utc_offset": -18000,
#             "statuses_count": 3799,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/456661258826031104/FQAt8OZH_normal.jpeg",
#             "description": "Official account of Fighting Illini wrestliing, updated by University of Illinois Athletic Communications http://t.co/iSs9XwBnZ1  #Illini",
#             "profile_background_color": "9AE4E8",
#             "id_str": "41606345",
#             "protected": false,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/486644702389612545/YD8DDfY2.png",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/486644702389612545/YD8DDfY2.png",
#             "default_profile": false,
#             "lang": "en",
#             "geo_enabled": false,
#             "profile_text_color": "333333",
#             "notifications": false,
#             "verified": false,
#             "profile_background_tile": false,
#             "is_translator": false,
#             "screen_name": "IlliniWrestling",
#             "name": "Illinois Wrestling",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/41606345/1404860347",
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDFFCC",
#             "favourites_count": 108,
#             "time_zone": "Central Time (US & Canada)"
#         },
#         "in_reply_to_user_id_str": null,
#         "lang": "en",
#         "in_reply_to_user_id": null,
#         "place": null,
#         "coordinates": null,
#         "in_reply_to_status_id": null,
#         "retweeted": false,
#         "contributors": null,
#         "favorited": false,
#         "text": "Another takedown. 9-4 Martinez. #Illini"
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "favorite_count": 0,
#     "geo": null,
#     "id_str": "574671140611751937",
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "retweet_count": 1,
#     "user": {
#         "followers_count": 780,
#         "listed_count": 4,
#         "location": "California \u2022 Illinois",
#         "id": 386583980,
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_location": null,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/558357432355676160/g20VSaGZ_normal.jpeg",
#         "default_profile_image": false,
#         "following": false,
#         "profile_use_background_image": true,
#         "profile_link_color": "FF0000",
#         "is_translation_enabled": false,
#         "follow_request_sent": false,
#         "friends_count": 579,
#         "url": null,
#         "created_at": "Fri Oct 07 14:47:51 +0000 2011",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "utc_offset": -25200,
#         "statuses_count": 13296,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/558357432355676160/g20VSaGZ_normal.jpeg",
#         "description": "McKendree University Wrestling | \u03a3\u03a3\u03a3 | #BeBlind2016 | IG: calisammie",
#         "profile_background_color": "FFFFFF",
#         "id_str": "386583980",
#         "protected": false,
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/448140425090449409/bo7soCa3.jpeg",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/448140425090449409/bo7soCa3.jpeg",
#         "default_profile": false,
#         "lang": "en",
#         "geo_enabled": true,
#         "profile_text_color": "3D1957",
#         "notifications": false,
#         "verified": false,
#         "profile_background_tile": true,
#         "is_translator": false,
#         "screen_name": "SammieNicoleB",
#         "name": "Samantha Barrientos",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/386583980/1398731534",
#         "contributors_enabled": false,
#         "profile_sidebar_fill_color": "7AC3EE",
#         "favourites_count": 1721,
#         "time_zone": "Pacific Time (US & Canada)"
#     },
#     "in_reply_to_user_id_str": null,
#     "lang": "en",
#     "in_reply_to_user_id": null,
#     "place": null,
#     "coordinates": null,
#     "in_reply_to_status_id": null,
#     "retweeted": false,
#     "contributors": null,
#     "favorited": false,
#     "text": "RT @IlliniWrestling: Another takedown. 9-4 Martinez. #Illini"
# }

# %%
q = "illini"
count = 3
search_results = twitter_api.search.tweets(q = q, count = count) # search_results contains two fields: "statuses" and "search_metadata" 
first_status = search_results['statuses'][0]
print("keys = ", first_status.keys()) # show the structure of the first tweet

print("\n\ntext = ", first_status["text"], "\n\nentities = ", first_status['entities'])
# Out:
# keys =  dict_keys(['in_reply_to_status_id_str', 'id', 'truncated', 'in_reply_to_screen_name', 'created_at', 'entities', 'retweeted_status', 'metadata', 'favorite_count', 'geo', 'id_str', 'source', 'retweet_count', 'user', 'in_reply_to_user_id_str', 'lang', 'in_reply_to_user_id', 'place', 'coordinates', 'in_reply_to_status_id', 'retweeted', 'contributors', 'favorited', 'text'])
#
#
# text =  RT @IlliniMGym: The amazing day for @MaestasCj continues. 15.35 on parallel bars, a new career high! #ILLINI
#
# entities =  {'symbols': [], 'user_mentions': [{'screen_name': 'IlliniMGym', 'id': 1952533632, 'id_str': '1952533632', 'name': "Illinois Men's Gym", 'indices': [3, 14]}, {'screen_name': 'MaestasCj', 'id': 471421851, 'id_str': '471421851', 'name': 'Cj Maestas™', 'indices': [36, 46]}], 'hashtags': [{'text': 'ILLINI', 'indices': [101, 108]}], 'urls': []}
